# %% [markdown]
# <h3><u><i>Plots of our test results</i></u></h3>
# <h4>Executed the same query with data of :
#
#     - Lines of data : 1.000
#     - Lines of data : 10.000
#     - Lines of data : 100.000
#     - Lines of data : 1.000.000
#     - Lines of data : 10.000.000
#
# Using :
#
#     - RDBMS
#     - Spark with 1-10 nodes as executors
#
# And executed each combination of the above for :
#
#     - 10 times
#
# The tests run on the cluster of the university :
#
#     - 11 nodes : 1 master and 10 slaves
#     - Each node is a SUN Fire X4100 Servers with 4 CPUs (Dual Core AMD Opteron στα 2193 MHz each CPU)
#     - Each node has 12GB or RAM
#     - For our tests we used 3GB on each node.
# </h4>
#
# ***

# %% [markdown]
# <h4>Loading the data of the csv to dataFrames : </h4>

# %%
import pandas as pd
import glob
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
import seaborn as sns
plt.style.use('ggplot')
# RDBMS
rdbms1_1K = pd.read_csv("1_RDBMS_1K-products.csv")
rdbms1_10K = pd.read_csv("1_RDBMS_10K-products.csv")
rdbms1_100K = pd.read_csv("1_RDBMS_100K-products.csv")
rdbms1_1M = pd.read_csv("1_RDBMS_1M-products.csv")
rdbms1_10M = pd.read_csv("1_RDBMS_10M-products.csv")

#SPARK 1 NODE
spark1_1K = pd.read_csv("1_Spark_1K-products.csv")
spark1_10K = pd.read_csv("1_Spark_10K-products.csv")
spark1_100K = pd.read_csv("1_Spark_100K-products.csv")
spark1_1M = pd.read_csv("1_Spark_1M-products.csv")
spark1_10M = pd.read_csv("1_Spark_10M-products.csv")

#SPARK 2 NODE
spark2_1K = pd.read_csv("2_Spark_1K-products.csv")
spark2_10K = pd.read_csv("2_Spark_10K-products.csv")
spark2_100K = pd.read_csv("2_Spark_100K-products.csv")
spark2_1M = pd.read_csv("2_Spark_1M-products.csv")
spark2_10M = pd.read_csv("2_Spark_10M-products.csv")

#SPARK 3 NODE
spark3_1K = pd.read_csv("3_Spark_1K-products.csv")
spark3_10K = pd.read_csv("3_Spark_10K-products.csv")
spark3_100K = pd.read_csv("3_Spark_100K-products.csv")
spark3_1M = pd.read_csv("3_Spark_1M-products.csv")
spark3_10M = pd.read_csv("3_Spark_10M-products.csv")

#SPARK 4 NODE
spark4_1K = pd.read_csv("4_Spark_1K-products.csv")
spark4_10K = pd.read_csv("4_Spark_10K-products.csv")
spark4_100K = pd.read_csv("4_Spark_100K-products.csv")
spark4_1M = pd.read_csv("4_Spark_1M-products.csv")
spark4_10M = pd.read_csv("4_Spark_10M-products.csv")

#SPARK 5 NODE
spark5_1K = pd.read_csv("5_Spark_1K-products.csv")
spark5_10K = pd.read_csv("5_Spark_10K-products.csv")
spark5_100K = pd.read_csv("5_Spark_100K-products.csv")
spark5_1M = pd.read_csv("5_Spark_1M-products.csv")
spark5_10M = pd.read_csv("5_Spark_10M-products.csv")

#SPARK 6 NODE
spark6_1K = pd.read_csv("6_Spark_1K-products.csv")
spark6_10K = pd.read_csv("6_Spark_10K-products.csv")
spark6_100K = pd.read_csv("6_Spark_100K-products.csv")
spark6_1M = pd.read_csv("6_Spark_1M-products.csv")
spark6_10M = pd.read_csv("6_Spark_10M-products.csv")

#SPARK 7 NODE
spark7_1K = pd.read_csv("7_Spark_1K-products.csv")
spark7_10K = pd.read_csv("7_Spark_10K-products.csv")
spark7_100K = pd.read_csv("7_Spark_100K-products.csv")
spark7_1M = pd.read_csv("7_Spark_1M-products.csv")
spark7_10M = pd.read_csv("7_Spark_10M-products.csv")

#SPARK 8 NODE
spark8_1K = pd.read_csv("8_Spark_1K-products.csv")
spark8_10K = pd.read_csv("8_Spark_10K-products.csv")
spark8_100K = pd.read_csv("8_Spark_100K-products.csv")
spark8_1M = pd.read_csv("8_Spark_1M-products.csv")
spark8_10M = pd.read_csv("8_Spark_10M-products.csv")

#SPARK 9 NODE
spark9_1K = pd.read_csv("9_Spark_1K-products.csv")
spark9_10K = pd.read_csv("9_Spark_10K-products.csv")
spark9_100K = pd.read_csv("9_Spark_100K-products.csv")
spark9_1M = pd.read_csv("9_Spark_1M-products.csv")
spark9_10M = pd.read_csv("9_Spark_10M-products.csv")

#SPARK 10 NODE
spark10_1K = pd.read_csv("10_Spark_1K-products.csv")
spark10_10K = pd.read_csv("10_Spark_10K-products.csv")
spark10_100K = pd.read_csv("10_Spark_100K-products.csv")
spark10_1M = pd.read_csv("10_Spark_1M-products.csv")
spark10_10M = pd.read_csv("10_Spark_10M-products.csv")

# %% [markdown]
# ***
#
# <h4>Plot of "Average time of query execution" : </h4>

# %%
average_query_time_1K = [rdbms1_1K["query_time"].mean()/1000, spark1_1K["query_time"].mean()/1000,
                         spark2_1K["query_time"].mean()/1000, spark3_1K["query_time"].mean()/1000,
                         spark4_1K["query_time"].mean()/1000, spark5_1K["query_time"].mean()/1000,
                         spark6_1K["query_time"].mean()/1000, spark7_1K["query_time"].mean()/1000,
                         spark8_1K["query_time"].mean()/1000, spark9_1K["query_time"].mean()/1000,
                         spark10_1K["query_time"].mean()/1000]

# %%
average_query_time_10K = [rdbms1_10K["query_time"].mean()/1000, spark1_10K["query_time"].mean()/1000,
                         spark2_10K["query_time"].mean()/1000, spark3_10K["query_time"].mean()/1000,
                         spark4_10K["query_time"].mean()/1000, spark5_10K["query_time"].mean()/1000,
                         spark6_10K["query_time"].mean()/1000, spark7_10K["query_time"].mean()/1000,
                         spark8_10K["query_time"].mean()/1000, spark9_10K["query_time"].mean()/1000,
                         spark10_10K["query_time"].mean()/1000]

# %%
average_query_time_100K = [rdbms1_100K["query_time"].mean()/1000, spark1_100K["query_time"].mean()/1000,
                         spark2_100K["query_time"].mean()/1000, spark3_100K["query_time"].mean()/1000,
                         spark4_100K["query_time"].mean()/1000, spark5_100K["query_time"].mean()/1000,
                         spark6_100K["query_time"].mean()/1000, spark7_100K["query_time"].mean()/1000,
                         spark8_100K["query_time"].mean()/1000, spark9_100K["query_time"].mean()/1000,
                         spark10_100K["query_time"].mean()/1000]

# %%
average_query_time_1M = [rdbms1_1M["query_time"].mean()/1000, spark1_1M["query_time"].mean()/1000,
                         spark2_1M["query_time"].mean()/1000, spark3_1M["query_time"].mean()/1000,
                         spark4_1M["query_time"].mean()/1000, spark5_1M["query_time"].mean()/1000,
                         spark6_1M["query_time"].mean()/1000, spark7_1M["query_time"].mean()/1000,
                         spark8_1M["query_time"].mean()/1000, spark9_1M["query_time"].mean()/1000,
                         spark10_1M["query_time"].mean()/1000]

# %%
average_query_time_10M = [rdbms1_10M["query_time"].mean()/1000, spark1_10M["query_time"].mean()/1000,
                         spark2_10M["query_time"].mean()/1000, spark3_10M["query_time"].mean()/1000,
                         spark4_10M["query_time"].mean()/1000, spark5_10M["query_time"].mean()/1000,
                         spark6_10M["query_time"].mean()/1000, spark7_10M["query_time"].mean()/1000,
                         spark8_10M["query_time"].mean()/1000, spark9_10M["query_time"].mean()/1000,
                         spark10_10M["query_time"].mean()/1000]

# %%
list_1K =[]
list_10K =[]
list_100K =[]
list_1M =[]
list_10M =[]
list_avg = [[] for j in range (0,6)]
list_avg[0] = ['1 Node', '2 Node', '3 Node', '4 Node', 
            '5 Node', '6 Node', '7 Node', '8 Node', '9 Node', '10 Node']
for i in average_query_time_1K[1:]:
    list_avg[1].append(round(((rdbms1_1K["query_time"].mean()/1000)-i)/(rdbms1_1K["query_time"].mean()/1000)*100,2))

for i in average_query_time_10K[1:]:
    list_avg[2].append(round(((rdbms1_10K["query_time"].mean()/1000)-i)/(rdbms1_10K["query_time"].mean()/1000)*100,2))

for i in average_query_time_100K[1:]:
    list_avg[3].append(round(((rdbms1_100K["query_time"].mean()/1000)-i)/(rdbms1_100K["query_time"].mean()/1000)*100,2))

for i in average_query_time_1M[1:]:
    list_avg[4].append(round(((rdbms1_1M["query_time"].mean()/1000)-i)/(rdbms1_1M["query_time"].mean()/1000)*100,2))

for i in average_query_time_10M[1:]:
    if (((rdbms1_10M["query_time"].mean()/1000)-i) < 0):
        list_avg[5].append(round(((rdbms1_10M["query_time"].mean()/1000)-i)/(rdbms1_10M["query_time"].mean()/1000)*100,2))
    else :
        list_avg[5].append(round(((i-rdbms1_10M["query_time"].mean()/1000))/(i)*100,2))

print(round(((rdbms1_10M["query_time"].mean()/1000)-spark10_10M["query_time"].mean()/1000)/(rdbms1_10M["query_time"].mean()/1000)*100,2))
# print(list_avg)
font_color = [[]]
print(list_avg)
font_color[0] = ['rgb(40,40,40)']
font_color[1:] = [['rgb(222, 109, 89)' if int(v) <= 0 else 'rgb(93, 175, 70)' for v in list_avg[j]] for j in range (1,6)]
list_avg = [[str(list_avg[j][i]) if j == 0 else '<b>' + str(list_avg[j][i]) + '%</b>' for i in range(0,10)] for j in range(0,6)]
print(font_color)
import plotly.graph_objects as go

headerColor = '#6a748a'
rowEvenColor = '#f7f7f7'
rowOddColor = '#e1e6ea'

fig = go.Figure(data=[go.Table(
  header=dict(
    values=['<b>Data</b>','1K', '10K', '100K', '1M', '10M'],
    line_color='darkslategray',
    fill_color=headerColor,
    align=['left','center'],
    font=dict(color='white', size=10)
  ),
  cells=dict(
    values=list_avg,
    line_color='darkslategray',
    font = dict(family="Arial", size=14, color=font_color),
    # 2-D list of colors for alternating rows
    fill_color = [[rowOddColor,rowEvenColor]*5],
    align = ['left', 'center'],
    height=30
    ))
])
fig.update_layout(width=1000, height=600)
fig.show()
# Out:
# 90.67
# [['1 Node', '2 Node', '3 Node', '4 Node', '5 Node', '6 Node', '7 Node', '8 Node', '9 Node', '10 Node'], [-52775.28, -42206.74, -42968.54, -43964.04, -49610.11, -56484.27, -55361.8, -56728.09, -59107.87, -60023.6], [-7167.63, -7959.67, -8903.44, -9461.3, -10131.65, -10120.43, -10928.57, -10629.11, -10476.67, -12528.75], [-849.2, -952.51, -1001.91, -1068.28, -1119.27, -1194.71, -1217.06, -1327.35, -1406.35, -1397.17], [-136.61, -62.83, -41.33, -34.27, -44.69, -73.41, -143.57, -21.09, -24.71, -16.07], [-62.88, -201.23, -328.94, -320.08, -423.76, -282.24, -366.92, -812.86, -904.54, -971.73]]
# ...

# %%
import plotly.graph_objects as go

prods = ['Aaaa', 'Bbbb', 'Cccc', 'Dddd', 'Eeee', 'Ffff']
vals = [-1.2, 2.3, 4.5, -2.5, 3.2, -0.5]
font_color = ['rgb(40,40,40)', ['rgb(255,0,0)' if v <= 0 else 'rgb(10,10,10)' for v in vals]]
print(font_color)
table_trace = go.Table(
                 columnwidth= [15]+[15],
                 columnorder=[0, 1],
                 header = dict(height = 50,
                               values = [['<b>Product</b>'], ['<b>Quantity</b>']],
                               line = dict(color='rgb(50,50,50)'),
                               align = ['left']*2,
                               font = dict(color=['rgb(45,45,45)']*2, size=14),
                             
                              ),
                 cells = dict(values = [prods, vals],
                              line = dict(color='#506784'),
                              align = ['left']*5,
                              font = dict(family="Arial", size=14, color=font_color),
                              format = [None, ",.2f"],
                             
                              height = 30,
                              fill = dict(color='rgb(245,245,245)'))
                             )
                 

layout = go.Layout(width=400, height=415, autosize=False, 
              title_text='Table title',
                   title_x=0.5, showlegend=False)
fig = go.Figure(data=[table_trace], layout=layout)
fig
# Out:
# ['rgb(40,40,40)', ['rgb(255,0,0)', 'rgb(10,10,10)', 'rgb(10,10,10)', 'rgb(255,0,0)', 'rgb(10,10,10)', 'rgb(255,0,0)']]
# <div>
#
#
#             <div id="8c7a12c3-1b5b-4b27-b5be-872a86d930e0" class="plotly-graph-div" style="height:415px; width:400px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("8c7a12c3-1b5b-4b27-b5be-872a86d930e0")) {
#                     Plotly.newPlot(
#                         '8c7a12c3-1b5b-4b27-b5be-872a86d930e0',
# ...

# %%
min_query_time_1K = [rdbms1_1K["query_time"].min()/1000, spark1_1K["query_time"].min()/1000,
                         spark2_1K["query_time"].min()/1000, spark3_1K["query_time"].min()/1000,
                         spark4_1K["query_time"].min()/1000, spark5_1K["query_time"].min()/1000,
                         spark6_1K["query_time"].min()/1000, spark7_1K["query_time"].min()/1000,
                         spark8_1K["query_time"].min()/1000, spark9_1K["query_time"].min()/1000,
                         spark10_1K["query_time"].min()/1000]


min_query_time_10K = [rdbms1_10K["query_time"].min()/1000, spark1_10K["query_time"].min()/1000,
                         spark2_10K["query_time"].min()/1000, spark3_10K["query_time"].min()/1000,
                         spark4_10K["query_time"].min()/1000, spark5_10K["query_time"].min()/1000,
                         spark6_10K["query_time"].min()/1000, spark7_10K["query_time"].min()/1000,
                         spark8_10K["query_time"].min()/1000, spark9_10K["query_time"].min()/1000,
                         spark10_10K["query_time"].min()/1000]

min_query_time_100K = [rdbms1_100K["query_time"].min()/1000, spark1_100K["query_time"].min()/1000,
                         spark2_100K["query_time"].min()/1000, spark3_100K["query_time"].min()/1000,
                         spark4_100K["query_time"].min()/1000, spark5_100K["query_time"].min()/1000,
                         spark6_100K["query_time"].min()/1000, spark7_100K["query_time"].min()/1000,
                         spark8_100K["query_time"].min()/1000, spark9_100K["query_time"].min()/1000,
                         spark10_100K["query_time"].min()/1000]

min_query_time_1M = [rdbms1_1M["query_time"].min()/1000, spark1_1M["query_time"].min()/1000,
                         spark2_1M["query_time"].min()/1000, spark3_1M["query_time"].min()/1000,
                         spark4_1M["query_time"].min()/1000, spark5_1M["query_time"].min()/1000,
                         spark6_1M["query_time"].min()/1000, spark7_1M["query_time"].min()/1000,
                         spark8_1M["query_time"].min()/1000, spark9_1M["query_time"].min()/1000,
                         spark10_1M["query_time"].min()/1000]

min_query_time_10M = [rdbms1_10M["query_time"].min()/1000, spark1_10M["query_time"].min()/1000,
                         spark2_10M["query_time"].min()/1000, spark3_10M["query_time"].min()/1000,
                         spark4_10M["query_time"].min()/1000, spark5_10M["query_time"].min()/1000,
                         spark6_10M["query_time"].min()/1000, spark7_10M["query_time"].min()/1000,
                         spark8_10M["query_time"].min()/1000, spark9_10M["query_time"].min()/1000,
                         spark10_10M["query_time"].min()/1000]

# %%
max_query_time_1K = [rdbms1_1K["query_time"].max()/1000, spark1_1K["query_time"].max()/1000,
                         spark2_1K["query_time"].max()/1000, spark3_1K["query_time"].max()/1000,
                         spark4_1K["query_time"].max()/1000, spark5_1K["query_time"].max()/1000,
                         spark6_1K["query_time"].max()/1000, spark7_1K["query_time"].max()/1000,
                         spark8_1K["query_time"].max()/1000, spark9_1K["query_time"].max()/1000,
                         spark10_1K["query_time"].max()/1000]


max_query_time_10K = [rdbms1_10K["query_time"].max()/1000, spark1_10K["query_time"].max()/1000,
                         spark2_10K["query_time"].max()/1000, spark3_10K["query_time"].max()/1000,
                         spark4_10K["query_time"].max()/1000, spark5_10K["query_time"].max()/1000,
                         spark6_10K["query_time"].max()/1000, spark7_10K["query_time"].max()/1000,
                         spark8_10K["query_time"].max()/1000, spark9_10K["query_time"].max()/1000,
                         spark10_10K["query_time"].max()/1000]

max_query_time_100K = [rdbms1_100K["query_time"].max()/1000, spark1_100K["query_time"].max()/1000,
                         spark2_100K["query_time"].max()/1000, spark3_100K["query_time"].max()/1000,
                         spark4_100K["query_time"].max()/1000, spark5_100K["query_time"].max()/1000,
                         spark6_100K["query_time"].max()/1000, spark7_100K["query_time"].max()/1000,
                         spark8_100K["query_time"].max()/1000, spark9_100K["query_time"].max()/1000,
                         spark10_100K["query_time"].max()/1000]

max_query_time_1M = [rdbms1_1M["query_time"].max()/1000, spark1_1M["query_time"].max()/1000,
                         spark2_1M["query_time"].max()/1000, spark3_1M["query_time"].max()/1000,
                         spark4_1M["query_time"].max()/1000, spark5_1M["query_time"].max()/1000,
                         spark6_1M["query_time"].max()/1000, spark7_1M["query_time"].max()/1000,
                         spark8_1M["query_time"].max()/1000, spark9_1M["query_time"].max()/1000,
                         spark10_1M["query_time"].max()/1000]

max_query_time_10M = [rdbms1_10M["query_time"].max()/1000, spark1_10M["query_time"].max()/1000,
                         spark2_10M["query_time"].max()/1000, spark3_10M["query_time"].max()/1000,
                         spark4_10M["query_time"].max()/1000, spark5_10M["query_time"].max()/1000,
                         spark6_10M["query_time"].max()/1000, spark7_10M["query_time"].max()/1000,
                         spark8_10M["query_time"].max()/1000, spark9_10M["query_time"].max()/1000,
                         spark10_10M["query_time"].max()/1000]

# %%
diff_query_time_1K = [a_i - b_i for a_i, b_i in zip(max_query_time_1K, min_query_time_1K)]
diff_query_time_10K = [a_i - b_i for a_i, b_i in zip(max_query_time_10K, min_query_time_10K)]
diff_query_time_100K = [a_i - b_i for a_i, b_i in zip(max_query_time_100K, min_query_time_100K)]
diff_query_time_1M = [a_i - b_i for a_i, b_i in zip(max_query_time_1M, min_query_time_1M)]
diff_query_time_10M = [a_i - b_i for a_i, b_i in zip(max_query_time_10M, min_query_time_10M)]

min_1K = [a_i - b_i for a_i, b_i in zip(average_query_time_1K, min_query_time_1K)]
max_1K = [a_i - b_i for a_i, b_i in zip(max_query_time_1K, average_query_time_1K)]
err_1K = [min_1K, max_1K]

min_10K = [a_i - b_i for a_i, b_i in zip(average_query_time_10K, min_query_time_10K)]
max_10K = [a_i - b_i for a_i, b_i in zip(max_query_time_10K, average_query_time_10K)]
err_10K = [min_10K, max_10K]

min_100K = [a_i - b_i for a_i, b_i in zip(average_query_time_100K, min_query_time_100K)]
max_100K = [a_i - b_i for a_i, b_i in zip(max_query_time_100K, average_query_time_100K)]
err_100K = [min_100K, max_100K]

min_1M = [a_i - b_i for a_i, b_i in zip(average_query_time_1M, min_query_time_1M)]
max_1M= [a_i - b_i for a_i, b_i in zip(max_query_time_1M, average_query_time_1M)]
err_1M = [min_1M, max_1M]

min_10M = [a_i - b_i for a_i, b_i in zip(average_query_time_10M, min_query_time_10M)]
max_10M = [a_i - b_i for a_i, b_i in zip(max_query_time_10M, average_query_time_10M)]
err_10M = [min_10M, max_10M]

# %%
indexes = ['RDBMS', '1 Node', '2 Node', '3 Node', '4 Node', 
            '5 Node', '6 Node', '7 Node', '8 Node', '9 Node', '10 Node']

average_query_time_df = pd.DataFrame({'1K': average_query_time_1K,
                                     'indexes': indexes
                                     }, index=indexes)

# %%
my_colors = [(0.317, 0.615, 0.960),(0.537, 0.219, 1),(0.756, 0.219, 1),(0.905, 0.219, 1),
             (1, 0.219, 0.737),(1, 0.219, 0.384),(1, 0.392, 0.219), (1, 0.584, 0.219),
             (1, 0.717, 0.219),(0.909, 0.937, 0.305),(0.470, 0.937, 0.305)]
colors = sns.color_palette('ch:3,-.2,dark=0.4',n_colors = 11)
ax = average_query_time_df.plot.bar(x='indexes', y='1K',color=colors, rot=0, figsize=(55,35), fontsize=40,
                                title="Average time of query execution for 1K Lines\n",
                                width=0.8,
                                linewidth=8,
                                edgecolor=(1,1,1),
                                legend=False,
                                yerr=[err_1K],
                                error_kw=dict(lw=5, capsize=30, capthick=5))
ax.set_xlabel("\nRDBMS/Nodes Running", fontsize=60)
ax.set_ylabel("Time in seconds\n", fontsize=60)
ax.title.set_fontsize(70)
ax.grid(True)
ax.set_facecolor((0.949, 0.960, 0.972))

for p in ax.patches:
    str(ax.text(p.get_x(), p.get_height()+0.1, np.round(p.get_height(),decimals=2), fontsize=35))

# %%
ax.figure.savefig('16Average time of query execution for 1K Lines', dpi=20)

# %%
average_query_time_df = pd.DataFrame({'10K': average_query_time_10K,
                                     'indexes': indexes
                                     }, index=indexes)

ax = average_query_time_df.plot.bar(x='indexes', y='10K',color=colors, rot=0, figsize=(55,35), fontsize=40,
                                title="Average time of query execution for 10K Lines\n",
                                width=0.8,
                                linewidth=8,
                                edgecolor=(1,1,1),
                                legend=False,
                                yerr=[err_10K],
                                error_kw=dict(lw=5, capsize=30, capthick=5))

ax.set_xlabel("\nRDBMS/Nodes Running", fontsize=60)
ax.set_ylabel("Time in seconds\n", fontsize=60)
ax.title.set_fontsize(70)
ax.grid(True)
ax.set_facecolor((0.949, 0.960, 0.972))

for p in ax.patches:
    str(ax.text(p.get_x(), p.get_height()+0.1, np.round(p.get_height(),decimals=2), fontsize=35))

# %%
ax.figure.savefig('Average time of query execution for 10K Lines', dpi=200)

# %%
average_query_time_df = pd.DataFrame({'100K': average_query_time_100K,
                                     'indexes': indexes
                                     }, index=indexes)

ax = average_query_time_df.plot.bar(x='indexes', y='100K',color=colors, rot=0, figsize=(55,35), fontsize=40,
                                title="Average time of query execution for 100K Lines\n",
                                width=0.8,
                                linewidth=8,
                                edgecolor=(1,1,1),
                                legend=False,
                                yerr=[err_100K],
                                error_kw=dict(lw=5, capsize=30, capthick=5))
ax.set_xlabel("\nRDBMS/Nodes Running", fontsize=60)
ax.set_ylabel("Time in seconds\n", fontsize=60)
ax.title.set_fontsize(70)
ax.grid(True)
ax.set_facecolor((0.949, 0.960, 0.972))

for p in ax.patches:
    str(ax.text(p.get_x(), p.get_height()+0.1, np.round(p.get_height(),decimals=2), fontsize=35))

# %%
ax.figure.savefig('Average time of query execution for 100K Lines', dpi=200)

# %%
average_query_time_df = pd.DataFrame({'1M': average_query_time_1M,
                                     'indexes': indexes
                                     }, index=indexes)

ax = average_query_time_df.plot.bar(x='indexes', y='1M',color=colors, rot=0, figsize=(55,35), fontsize=40,
                                title="Average time of query execution for 1M Lines\n",
                                width=0.8,
                                linewidth=8,
                                edgecolor=(1,1,1),
                                legend=False,
                                yerr=[err_1M],
                                error_kw=dict(lw=5, capsize=30, capthick=5))
ax.set_xlabel("\nRDBMS/Nodes Running", fontsize=60)
ax.set_ylabel("Time in seconds\n", fontsize=60)
ax.title.set_fontsize(70)
ax.grid(True)
ax.set_facecolor((0.949, 0.960, 0.972))

for p in ax.patches:
    str(ax.text(p.get_x(), p.get_height()+0.1, np.round(p.get_height(),decimals=2), fontsize=35))

# %%
ax.figure.savefig('Average time of query execution for 1M Lines', dpi=200)

# %%
average_query_time_df = pd.DataFrame({'10M': average_query_time_10M,
                                     'indexes': indexes
                                     }, index=indexes)

ax = average_query_time_df.plot.bar(x='indexes', y='10M',color=colors, rot=0, figsize=(55,35), fontsize=40,
                                title="Average time of query execution for 10M Lines\n",
                                width=0.8,
                                linewidth=8,
                                edgecolor=(1,1,1),
                                legend=False,
                                yerr=[err_10M],
                                error_kw=dict(lw=5, capsize=30, capthick=5))
ax.set_xlabel("\nRDBMS/Nodes Running", fontsize=60)
ax.set_ylabel("Time in seconds\n", fontsize=60)
ax.title.set_fontsize(70)
ax.grid(True)
ax.set_facecolor((0.949, 0.960, 0.972))

for p in ax.patches:
    str(ax.text(p.get_x(), p.get_height()+1, np.round(p.get_height(),decimals=2), fontsize=35))

# %%
ax.figure.savefig('Average time of query execution for 10M Lines', dpi=200)

# %%
indexes = ['1st Run', '2nd Run', '3rd Run','4th Run', 
            '5th Run', '6th Run', '7th Run', '8th Run', '9th Run', '10th Run']
print(spark10_1K.query_time)
ss = pd.DataFrame({'10S': (spark10_1K.query_time/1000).tolist(),'indexes': indexes}, index=indexes)
print(ss)
colors = sns.color_palette('ch:0.60, -.0500, +.500,dark=0.3',n_colors = 11)
ax = ss.plot.bar(x='indexes', y='10S',color=colors, rot=0, figsize=(55,35), fontsize=40,
                                title="Average time of query execution\n",
                                width=0.8,
                                linewidth=8,
                                edgecolor=(1,1,1),
                                legend=False)

list_c = []
for p in ax.patches:
    str(ax.text(p.get_x(), p.get_height()+1, np.round(p.get_height(),decimals=2), fontsize=35))
    list_c.append(p.get_height())
s_c = sns.color_palette("OrRd", 10)
s_c.reverse()
n_c = [0 for i in range(0,10)]
for i in range(0,10):
    n_c[list_c.index(max(list_c))] = s_c[i]
    list_c[list_c.index(max(list_c))] = 0
Z = [x for _,x in sorted(zip(list_c,colors))]
ax = ss.plot.bar(x='indexes', y='10S',color=n_c, rot=0, figsize=(55,35), fontsize=40,
                                title="Query execution times with 10 Nodes\n",
                                width=0.8,
                                linewidth=8,
                                edgecolor=(1,1,1),
                                legend=False)


ax.set_xlabel("\nRound of run", fontsize=60)
ax.set_ylabel("Time in seconds\n", fontsize=60)
ax.title.set_fontsize(70)
ax.grid(True)
ax.set_facecolor((0.992, 0.968, 0.964))
for p in ax.patches:
    str(ax.text(p.get_x()+p.get_width()/4, p.get_height()+0.1, np.round(p.get_height(),decimals=2), fontsize=35))
    list_c.append(p.get_height())
# Out:
# 0    14892
# 1     7485
# 2     3850
# 3     5471
# 4     2980
# 5     4373
# 6     3123
# 7     4146
# 8     4101
# 9     3089
# Name: query_time, dtype: int64
#              10S   indexes
# 1st Run   14.892   1st Run
# 2nd Run    7.485   2nd Run
# 3rd Run    3.850   3rd Run
# 4th Run    5.471   4th Run
# 5th Run    2.980   5th Run
# 6th Run    4.373   6th Run
# 7th Run    3.123   7th Run
# 8th Run    4.146   8th Run
# 9th Run    4.101   9th Run
# 10th Run   3.089  10th Run

# %%
ax.figure.savefig('Query execution times with 10 Nodes', dpi=200)

# %%
stacked_query_time = [rdbms1_10M["query_time"].mean()/1000, spark10_10M["query_time"].mean()/1000]
stacked_result_time = [rdbms1_10M["result_time"].mean()/1000, spark10_10M["result_time"].mean()/1000]
stacked_output_time = [rdbms1_10M["output_time"].mean()/1000, spark10_10M["output_time"].mean()/1000]

stacked_spark10 = [spark10_10M["query_time"].mean()/1000, spark10_10M["result_time"].mean()/1000,
                         spark10_10M["output_time"].mean()/1000]

index_aqt = ['RDBMS', 'Spark 10 Nodes']

stacked_df = pd.DataFrame({'Query Time': stacked_query_time,
                                     'Result Time': stacked_result_time,
                            'Output Time': stacked_output_time}, index=index_aqt)

# colors = sns.color_palette('ch:2.40, -.200, +.400,dark=0.3',n_colors = 3)
my_colors = [(0.545, 0.764, 0.913),(0.964, 0.454, 0.486),(0.627, 0.972, 0.607)]
ax = stacked_df.plot.bar(color=my_colors, rot=0, figsize=(55,35), fontsize=60,
                                title="Stacked average total time comparing RDBMS vs Spark 10 Nodes.png\n",
                                width=0.5,
                                linewidth=8,
                                edgecolor=(1,1,1),
                                legend=True,
                                stacked=True)
ax.legend(fontsize=60, facecolor='snow')
ax.set_xlabel("\nSystem Running", fontsize=60)
ax.set_ylabel("Time in seconds\n", fontsize=60)
ax.title.set_fontsize(70)
ax.grid(True)
ax.set_facecolor((0.949, 0.960, 0.972))
for p in ax.patches:
    width, height = p.get_width(), p.get_height()
    x, y = p.get_xy() 
    ax.text(x+width*1.09, 
            y+height/2, 
            np.round(height,decimals=2), 
            horizontalalignment='center', 
            verticalalignment='center', fontsize=40)
value1 = ax.patches[0].get_height() + ax.patches[2].get_height() + ax.patches[4].get_height()
value2 = ax.patches[1].get_height() + ax.patches[3].get_height() + ax.patches[5].get_height()
str(ax.text(ax.patches[0].get_x()+ ax.patches[0].get_width()/2.5, value1+2, np.round(value1,decimals=2), fontsize=45))
str(ax.text(ax.patches[3].get_x()+ ax.patches[3].get_width()/2.5, value2+2, np.round(value2,decimals=2), fontsize=45))
print(ax.patches[0].get_height())
print(ax.patches[1].get_height())
print(ax.patches[2].get_height())
print(ax.patches[3].get_height())
print(ax.patches[4].get_height())
print(ax.patches[5].get_height())
ax.patches[1]
# Out:
# 139.36929999999998
# 13.0042
# 2.6156000000000006
# 1.6263999999999896
# 12.518
# 9.837299999999999

# %%
ax.figure.savefig('Stacked average total time comparing RDBMS vs Spark 10 Nodes.png', dpi=200)

# %%
index_aqt = ['RDBMS', '1Node', '2Node', '3Node', '4Node', 
            '5Node', '6Node', '7Node', '8Node', '9Node', '10Node']
average_query_time_df = pd.DataFrame({'1K': average_query_time_1K,
                                     '10K': average_query_time_10K,
                                     '100K': average_query_time_100K,
                                     '1M': average_query_time_1M,
                                     '10M': average_query_time_10M}, index=index_aqt)

# %%
ax = average_query_time_df.plot.bar(rot=0, figsize=(45,25), fontsize=40,
                                    title="Average time of query execution for all data\n",
                                    width=0.95,
                                    color=['mediumslateblue', 'orangered', 'mediumseagreen', 'gold', 'cornflowerblue'],
                                    linewidth=4,
                                    edgecolor=(1,1,1),)
ax.legend(fontsize=40, facecolor='snow')
ax.set_xlabel("\nRDBMS/Nodes Running", fontsize=50)
ax.set_ylabel("Time in seconds\n", fontsize=50)
ax.title.set_fontsize(60)
ax.grid(True)
ax.set_facecolor((0.949, 0.960, 0.972))

for p in ax.patches:
    str(ax.text(p.get_x()+ p.get_width()/6, p.get_height()+1, np.round(p.get_height(),decimals=2), fontsize=25, rotation=90))

# %%
ax.figure.savefig('Average time of query execution for all data.png', dpi=200)

# %% [markdown]
# ***
#
# <h4>Plot of "Mean time of query execution RDBMS vs Spark 10 Nodes" : </h4>

# %%
rdbms_query_time = [rdbms1_1K["query_time"].mean(), rdbms1_10K["query_time"].mean(), rdbms1_100K["query_time"].mean(),
                   rdbms1_1M["query_time"].mean(), rdbms1_10M["query_time"].mean()]

spark10_query_time = [spark10_1K["query_time"].mean(), spark10_10K["query_time"].mean(), spark10_100K["query_time"].mean(),
                   spark10_1M["query_time"].mean(), spark10_10M["query_time"].mean()]

index_aqt = ['1K', '10K', '100K', '1M', '10M']
mean2_query_time_df = pd.DataFrame({'RDBMS': rdbms_query_time,
                                     'Spark 10 Nodes': spark10_query_time}, index=index_aqt)

ax = mean2_query_time_df.plot.bar(rot=0, figsize=(45,25), fontsize=30,
                                    title="Average time of query execution comparing RDBMS vs Spark 10 Nodes\n",
                                    width=0.85,
                                    color=['cornflowerblue', 'darkorange'])
ax.legend(fontsize=30, facecolor='snow')
ax.set_xlabel("\nLines of data", fontsize=30)
ax.set_ylabel("Time in ms\n", fontsize=30)
ax.title.set_fontsize(50)
for p in ax.patches:
    str(ax.text(p.get_x() + p.get_width()/6, p.get_height()+1000, np.round(p.get_height(),decimals=2), fontsize=35))

# ax.figure.savefig('Average time of query execution RDBMS vs Spark 10 Nodes.png', dpi=200)
print()

# %% [markdown]
# ***
#
# <h4>Plot of "Max time of query execution" : </h4>

# %%
max_query_time_1K = [rdbms1_1K["query_time"].max(), spark1_1K["query_time"].max(),
                         spark2_1K["query_time"].max(), spark3_1K["query_time"].max(),
                         spark4_1K["query_time"].max(), spark5_1K["query_time"].max(),
                         spark6_1K["query_time"].max(), spark7_1K["query_time"].max(),
                         spark8_1K["query_time"].max(), spark9_1K["query_time"].max(),
                         spark10_1K["query_time"].max()]

# %%
max_query_time_10K = [rdbms1_10K["query_time"].max(), spark1_10K["query_time"].max(),
                         spark2_10K["query_time"].max(), spark3_10K["query_time"].max(),
                         spark4_10K["query_time"].max(), spark5_10K["query_time"].max(),
                         spark6_10K["query_time"].max(), spark7_10K["query_time"].max(),
                         spark8_10K["query_time"].max(), spark9_10K["query_time"].max(),
                         spark10_10K["query_time"].max()]

# %%
max_query_time_100K = [rdbms1_100K["query_time"].max(), spark1_100K["query_time"].max(),
                         spark2_100K["query_time"].max(), spark3_100K["query_time"].max(),
                         spark4_100K["query_time"].max(), spark5_100K["query_time"].max(),
                         spark6_100K["query_time"].max(), spark7_100K["query_time"].max(),
                         spark8_100K["query_time"].max(), spark9_100K["query_time"].max(),
                         spark10_100K["query_time"].max()]

# %%
max_query_time_1M = [rdbms1_1M["query_time"].max(), spark1_1M["query_time"].max(),
                         spark2_1M["query_time"].max(), spark3_1M["query_time"].max(),
                         spark4_1M["query_time"].max(), spark5_1M["query_time"].max(),
                         spark6_1M["query_time"].max(), spark7_1M["query_time"].max(),
                         spark8_1M["query_time"].max(), spark9_1M["query_time"].max(),
                         spark10_1M["query_time"].max()]

# %%
max_query_time_10M = [rdbms1_10M["query_time"].max(), spark1_10M["query_time"].max(),
                         spark2_10M["query_time"].max(), spark3_10M["query_time"].max(),
                         spark4_10M["query_time"].max(), spark5_10M["query_time"].max(),
                         spark6_10M["query_time"].max(), spark7_10M["query_time"].max(),
                         spark8_10M["query_time"].max(), spark9_10M["query_time"].max(),
                         spark10_10M["query_time"].max()]

# %%
index_aqt = ['RDBMS', '1Node', '2Node', '3Node', '4Node', 
            '5Node', '6Node', '7Node', '8Node', '9Node', '10Node']
max_query_time_df = pd.DataFrame({'1K': max_query_time_1K,
                                     '10K': max_query_time_10K,
                                     '100K': max_query_time_100K,
                                     '1M': max_query_time_1M,
                                     '10M': max_query_time_10M}, index=index_aqt)

# %%
ax = max_query_time_df.plot.bar(rot=0, figsize=(45,25), fontsize=30,
                                    title="Max time of query execution\n",
                                    width=0.95,
                                    color=['mediumslateblue', 'orangered', 'mediumseagreen', 'gold', 'cornflowerblue'])
ax.legend(fontsize=30, facecolor='snow')
ax.set_xlabel("\nRDBMS/Nodes Running", fontsize=30)
ax.set_ylabel("Time in ms\n", fontsize=30)
ax.title.set_fontsize(50)

for p in ax.patches:
    str(ax.text(p.get_x()+ p.get_width()/6
                , p.get_height()+1500, np.round(p.get_height(),decimals=2), fontsize=25, rotation=90))
    
print()

# %%
ax.figure.savefig('Max time of query execution.png', dpi=200)

# %% [markdown]
# ***
#
# <h4>Plot of "Max time of query execution comparing RDBMS vs Spark 10 Nodes" : </h4>

# %%
rdbms_query_time = [rdbms1_1K["query_time"].max(), rdbms1_10K["query_time"].max(), rdbms1_100K["query_time"].max(),
                   rdbms1_1M["query_time"].max(), rdbms1_10M["query_time"].max()]

# %%
spark10_query_time = [spark10_1K["query_time"].max(), spark10_10K["query_time"].max(), spark10_100K["query_time"].max(),
                   spark10_1M["query_time"].max(), spark10_10M["query_time"].max()]

# %%
index_aqt = ['1K', '10K', '100K', '1M', '10M']
max2_query_time_df = pd.DataFrame({'RDBMS': rdbms_query_time,
                                     'Spark 10 Nodes': spark10_query_time}, index=index_aqt)

# %%
ax = max2_query_time_df.plot.bar(rot=0, figsize=(45,25), fontsize=30,
                                    title="Max time of query execution comparing RDBMS vs Spark 10 Nodes\n",
                                    width=0.85,
                                    color=['cornflowerblue', 'darkorange'])
ax.legend(fontsize=30, facecolor='white')
ax.set_xlabel("\nLines of data", fontsize=30)
ax.set_ylabel("Time in ms\n", fontsize=30)
ax.title.set_fontsize(50)
for p in ax.patches:
    str(ax.text(p.get_x() + p.get_width()/4, p.get_height()+1000, np.round(p.get_height(),decimals=2), fontsize=35))
    
print('Difference between times : \n')
print(max2_query_time_df['RDBMS'] - max2_query_time_df['Spark 10 Nodes'])
print()

# %%
ax.figure.savefig('Max time of query execution RDBMS vs Spark 10 Nodes.png', dpi=200)

# %%
rdbms1_100K.describe()

# %%
rdbms_query_time = [rdbms1_1K["query_time"].min(), rdbms1_10K["query_time"].min(), rdbms1_100K["query_time"].min(),
                   rdbms1_1M["query_time"].min(), rdbms1_10M["query_time"].min()]

spark10_query_time = [spark10_1K["query_time"].min(), spark10_10K["query_time"].min(), spark10_100K["query_time"].min(),
                   spark10_1M["query_time"].min(), spark10_10M["query_time"].min()]

index_aqt = ['1K', '10K', '100K', '1M', '10M']

min2_query_time_df = pd.DataFrame({'RDBMS': rdbms_query_time,
                                     'Spark 10 Nodes': spark10_query_time}, index=index_aqt)
ax = min2_query_time_df.plot.bar(rot=0, figsize=(45,25), fontsize=30,
                                    title="Min time of query execution comparing RDBMS vs Spark 10 Nodes\n",
                                    width=0.85,
                                    color=['cornflowerblue', 'darkorange'])

ax.legend(fontsize=30, facecolor='white')
ax.set_xlabel("\nLines of data", fontsize=30)
ax.set_ylabel("Time in ms\n", fontsize=30)
ax.title.set_fontsize(50)
for p in ax.patches:
    str(ax.text(p.get_x() + p.get_width()/4, p.get_height()+1000, np.round(p.get_height(),decimals=2), fontsize=35))

print('Difference between times : \n')
print(min2_query_time_df['RDBMS'] - min2_query_time_df['Spark 10 Nodes'])
print()
ax.figure.savefig('Min time of query execution RDBMS vs Spark 10 Nodes.png', dpi=200)

# %%
average_result_time_1K = [rdbms1_1K["result_time"].mean(), spark1_1K["result_time"].mean(),
                         spark2_1K["result_time"].mean(), spark3_1K["result_time"].mean(),
                         spark4_1K["result_time"].mean(), spark5_1K["result_time"].mean(),
                         spark6_1K["result_time"].mean(), spark7_1K["result_time"].mean(),
                         spark8_1K["result_time"].mean(), spark9_1K["result_time"].mean(),
                         spark10_1K["result_time"].mean()]

average_result_time_10K = [rdbms1_10K["result_time"].mean(), spark1_10K["result_time"].mean(),
                         spark2_10K["result_time"].mean(), spark3_10K["result_time"].mean(),
                         spark4_10K["result_time"].mean(), spark5_10K["result_time"].mean(),
                         spark6_10K["result_time"].mean(), spark7_10K["result_time"].mean(),
                         spark8_10K["result_time"].mean(), spark9_10K["result_time"].mean(),
                         spark10_10K["result_time"].mean()]

average_result_time_100K = [rdbms1_100K["result_time"].mean(), spark1_100K["result_time"].mean(),
                         spark2_100K["result_time"].mean(), spark3_100K["result_time"].mean(),
                         spark4_100K["result_time"].mean(), spark5_100K["result_time"].mean(),
                         spark6_100K["result_time"].mean(), spark7_100K["result_time"].mean(),
                         spark8_100K["result_time"].mean(), spark9_100K["result_time"].mean(),
                         spark10_100K["result_time"].mean()]

average_result_time_1M = [rdbms1_1M["result_time"].mean(), spark1_1M["result_time"].mean(),
                         spark2_1M["result_time"].mean(), spark3_1M["result_time"].mean(),
                         spark4_1M["result_time"].mean(), spark5_1M["result_time"].mean(),
                         spark6_1M["result_time"].mean(), spark7_1M["result_time"].mean(),
                         spark8_1M["result_time"].mean(), spark9_1M["result_time"].mean(),
                         spark10_1M["result_time"].mean()]

average_result_time_10M = [rdbms1_10M["result_time"].mean(), spark1_10M["result_time"].mean(),
                         spark2_10M["result_time"].mean(), spark3_10M["result_time"].mean(),
                         spark4_10M["result_time"].mean(), spark5_10M["result_time"].mean(),
                         spark6_10M["result_time"].mean(), spark7_10M["result_time"].mean(),
                         spark8_10M["result_time"].mean(), spark9_10M["result_time"].mean(),
                         spark10_10M["result_time"].mean()]

index_aqt = ['RDBMS', '1Node', '2Node', '3Node', '4Node', 
            '5Node', '6Node', '7Node', '8Node', '9Node', '10Node']

average_result_time_df = pd.DataFrame({'1K': average_result_time_1K,
                                     '10K': average_result_time_10K,
                                     '100K': average_result_time_100K,
                                     '1M': average_result_time_1M,
                                     '10M': average_result_time_10M}, index=index_aqt)

ax = average_result_time_df.plot.bar(rot=0, figsize=(45,25), fontsize=30,
                                    title="Average time of result execution\n",
                                    width=0.95,
                                    color=['mediumslateblue', 'orangered', 'mediumseagreen', 'gold', 'cornflowerblue'])
ax.legend(fontsize=30, facecolor='snow')
ax.set_xlabel("\nRDBMS/Nodes Running", fontsize=30)
ax.set_ylabel("Time in ms\n", fontsize=30)
ax.title.set_fontsize(50)

for p in ax.patches:
    str(ax.text(p.get_x()+ p.get_width()/6, p.get_height()+50, np.round(p.get_height(),decimals=2), fontsize=30, rotation=90))

# %%
min3_result_time_1K = [rdbms1_1K["result_time"].min(), spark1_1K["result_time"].min(),
                         spark2_1K["result_time"].min(), spark3_1K["result_time"].min(),
                         spark4_1K["result_time"].min(), spark5_1K["result_time"].min(),
                         spark6_1K["result_time"].min(), spark7_1K["result_time"].min(),
                         spark8_1K["result_time"].min(), spark9_1K["result_time"].min(),
                         spark10_1K["result_time"].min()]

min3_result_time_10K = [rdbms1_10K["result_time"].min(), spark1_10K["result_time"].min(),
                         spark2_10K["result_time"].min(), spark3_10K["result_time"].min(),
                         spark4_10K["result_time"].min(), spark5_10K["result_time"].min(),
                         spark6_10K["result_time"].min(), spark7_10K["result_time"].min(),
                         spark8_10K["result_time"].min(), spark9_10K["result_time"].min(),
                         spark10_10K["result_time"].min()]

min3_result_time_100K = [rdbms1_100K["result_time"].min(), spark1_100K["result_time"].min(),
                         spark2_100K["result_time"].min(), spark3_100K["result_time"].min(),
                         spark4_100K["result_time"].min(), spark5_100K["result_time"].min(),
                         spark6_100K["result_time"].min(), spark7_100K["result_time"].min(),
                         spark8_100K["result_time"].min(), spark9_100K["result_time"].min(),
                         spark10_100K["result_time"].min()]

min3_result_time_1M = [rdbms1_1M["result_time"].min(), spark1_1M["result_time"].min(),
                         spark2_1M["result_time"].min(), spark3_1M["result_time"].min(),
                         spark4_1M["result_time"].min(), spark5_1M["result_time"].min(),
                         spark6_1M["result_time"].min(), spark7_1M["result_time"].min(),
                         spark8_1M["result_time"].min(), spark9_1M["result_time"].min(),
                         spark10_1M["result_time"].min()]

min3_result_time_10M = [rdbms1_10M["result_time"].min(), spark1_10M["result_time"].min(),
                         spark2_10M["result_time"].min(), spark3_10M["result_time"].min(),
                         spark4_10M["result_time"].min(), spark5_10M["result_time"].min(),
                         spark6_10M["result_time"].min(), spark7_10M["result_time"].min(),
                         spark8_10M["result_time"].min(), spark9_10M["result_time"].min(),
                         spark10_10M["result_time"].min()]

index_aqt = ['RDBMS', '1Node', '2Node', '3Node', '4Node', 
            '5Node', '6Node', '7Node', '8Node', '9Node', '10Node']

min3_result_time_df = pd.DataFrame({'1K': min3_result_time_1K,
                                     '10K': min3_result_time_10K,
                                     '100K': min3_result_time_100K,
                                     '1M': min3_result_time_1M,
                                     '10M': min3_result_time_10M}, index=index_aqt)

ax = min3_result_time_df.plot.bar(rot=0, figsize=(45,25), fontsize=30,
                                    title="min3 time of result execution\n",
                                    width=0.95,
                                    color=['mediumslateblue', 'orangered', 'mediumseagreen', 'gold', 'cornflowerblue'])
ax.legend(fontsize=30, facecolor='snow')
ax.set_xlabel("\nRDBMS/Nodes Running", fontsize=30)
ax.set_ylabel("Time in ms\n", fontsize=30)
ax.title.set_fontsize(50)

for p in ax.patches:
    str(ax.text(p.get_x()+ p.get_width()/6, p.get_height()+50, np.round(p.get_height(),decimals=2), fontsize=30, rotation=90))

# %%
max3_result_time_1K = [rdbms1_1K["result_time"].max(), spark1_1K["result_time"].max(),
                         spark2_1K["result_time"].max(), spark3_1K["result_time"].max(),
                         spark4_1K["result_time"].max(), spark5_1K["result_time"].max(),
                         spark6_1K["result_time"].max(), spark7_1K["result_time"].max(),
                         spark8_1K["result_time"].max(), spark9_1K["result_time"].max(),
                         spark10_1K["result_time"].max()]

max3_result_time_10K = [rdbms1_10K["result_time"].max(), spark1_10K["result_time"].max(),
                         spark2_10K["result_time"].max(), spark3_10K["result_time"].max(),
                         spark4_10K["result_time"].max(), spark5_10K["result_time"].max(),
                         spark6_10K["result_time"].max(), spark7_10K["result_time"].max(),
                         spark8_10K["result_time"].max(), spark9_10K["result_time"].max(),
                         spark10_10K["result_time"].max()]

max3_result_time_100K = [rdbms1_100K["result_time"].max(), spark1_100K["result_time"].max(),
                         spark2_100K["result_time"].max(), spark3_100K["result_time"].max(),
                         spark4_100K["result_time"].max(), spark5_100K["result_time"].max(),
                         spark6_100K["result_time"].max(), spark7_100K["result_time"].max(),
                         spark8_100K["result_time"].max(), spark9_100K["result_time"].max(),
                         spark10_100K["result_time"].max()]

max3_result_time_1M = [rdbms1_1M["result_time"].max(), spark1_1M["result_time"].max(),
                         spark2_1M["result_time"].max(), spark3_1M["result_time"].max(),
                         spark4_1M["result_time"].max(), spark5_1M["result_time"].max(),
                         spark6_1M["result_time"].max(), spark7_1M["result_time"].max(),
                         spark8_1M["result_time"].max(), spark9_1M["result_time"].max(),
                         spark10_1M["result_time"].max()]

max3_result_time_10M = [rdbms1_10M["result_time"].max(), spark1_10M["result_time"].max(),
                         spark2_10M["result_time"].max(), spark3_10M["result_time"].max(),
                         spark4_10M["result_time"].max(), spark5_10M["result_time"].max(),
                         spark6_10M["result_time"].max(), spark7_10M["result_time"].max(),
                         spark8_10M["result_time"].max(), spark9_10M["result_time"].max(),
                         spark10_10M["result_time"].max()]

index_aqt = ['RDBMS', '1Node', '2Node', '3Node', '4Node', 
            '5Node', '6Node', '7Node', '8Node', '9Node', '10Node']

max3_result_time_df = pd.DataFrame({'1K': max3_result_time_1K,
                                     '10K': max3_result_time_10K,
                                     '100K': max3_result_time_100K,
                                     '1M': max3_result_time_1M,
                                     '10M': max3_result_time_10M}, index=index_aqt)

ax = max3_result_time_df.plot.bar(rot=0, figsize=(45,25), fontsize=30,
                                    title="max3 time of result execution\n",
                                    width=0.95,
                                    color=['mediumslateblue', 'orangered', 'mediumseagreen', 'gold', 'cornflowerblue'])
ax.legend(fontsize=30, facecolor='snow')
ax.set_xlabel("\nRDBMS/Nodes Running", fontsize=30)
ax.set_ylabel("Time in ms\n", fontsize=30)
ax.title.set_fontsize(50)

for p in ax.patches:
    str(ax.text(p.get_x()+ p.get_width()/6, p.get_height()+100, np.round(p.get_height(),decimals=2), fontsize=30, rotation=90))

# %%
average_output_time_1K = [rdbms1_1K["output_time"].mean(), spark1_1K["output_time"].mean(),
                         spark2_1K["output_time"].mean(), spark3_1K["output_time"].mean(),
                         spark4_1K["output_time"].mean(), spark5_1K["output_time"].mean(),
                         spark6_1K["output_time"].mean(), spark7_1K["output_time"].mean(),
                         spark8_1K["output_time"].mean(), spark9_1K["output_time"].mean(),
                         spark10_1K["output_time"].mean()]

average_output_time_10K = [rdbms1_10K["output_time"].mean(), spark1_10K["output_time"].mean(),
                         spark2_10K["output_time"].mean(), spark3_10K["output_time"].mean(),
                         spark4_10K["output_time"].mean(), spark5_10K["output_time"].mean(),
                         spark6_10K["output_time"].mean(), spark7_10K["output_time"].mean(),
                         spark8_10K["output_time"].mean(), spark9_10K["output_time"].mean(),
                         spark10_10K["output_time"].mean()]

average_output_time_100K = [rdbms1_100K["output_time"].mean(), spark1_100K["output_time"].mean(),
                         spark2_100K["output_time"].mean(), spark3_100K["output_time"].mean(),
                         spark4_100K["output_time"].mean(), spark5_100K["output_time"].mean(),
                         spark6_100K["output_time"].mean(), spark7_100K["output_time"].mean(),
                         spark8_100K["output_time"].mean(), spark9_100K["output_time"].mean(),
                         spark10_100K["output_time"].mean()]

average_output_time_1M = [rdbms1_1M["output_time"].mean(), spark1_1M["output_time"].mean(),
                         spark2_1M["output_time"].mean(), spark3_1M["output_time"].mean(),
                         spark4_1M["output_time"].mean(), spark5_1M["output_time"].mean(),
                         spark6_1M["output_time"].mean(), spark7_1M["output_time"].mean(),
                         spark8_1M["output_time"].mean(), spark9_1M["output_time"].mean(),
                         spark10_1M["output_time"].mean()]

average_output_time_10M = [rdbms1_10M["output_time"].mean(), spark1_10M["output_time"].mean(),
                         spark2_10M["output_time"].mean(), spark3_10M["output_time"].mean(),
                         spark4_10M["output_time"].mean(), spark5_10M["output_time"].mean(),
                         spark6_10M["output_time"].mean(), spark7_10M["output_time"].mean(),
                         spark8_10M["output_time"].mean(), spark9_10M["output_time"].mean(),
                         spark10_10M["output_time"].mean()]

index_aqt = ['RDBMS', '1Node', '2Node', '3Node', '4Node', 
            '5Node', '6Node', '7Node', '8Node', '9Node', '10Node']

average_output_time_df = pd.DataFrame({'1K': average_output_time_1K,
                                     '10K': average_output_time_10K,
                                     '100K': average_output_time_100K,
                                     '1M': average_output_time_1M,
                                     '10M': average_output_time_10M}, index=index_aqt)

ax = average_output_time_df.plot.bar(rot=0, figsize=(45,25), fontsize=30,
                                    title="Average time of result execution\n",
                                    width=0.95,
                                    color=['mediumslateblue', 'orangered', 'mediumseagreen', 'gold', 'cornflowerblue'])
ax.legend(fontsize=30, facecolor='snow')
ax.set_xlabel("\nRDBMS/Nodes Running", fontsize=30)
ax.set_ylabel("Time in ms\n", fontsize=30)
ax.title.set_fontsize(50)

for p in ax.patches:
    str(ax.text(p.get_x()+ p.get_width()/6, p.get_height()+100, np.round(p.get_height(),decimals=2), fontsize=25, rotation=90))

# %%
rdbms1_100K.describe()

# %%
stacked_query_time = [rdbms1_10M["query_time"].mean(), spark10_10M["query_time"].mean()]
stacked_result_time = [rdbms1_10M["result_time"].mean(), spark10_10M["result_time"].mean()]
stacked_output_time = [rdbms1_10M["output_time"].mean(), spark10_10M["output_time"].mean()]

stacked_spark10 = [spark10_10M["query_time"].mean(), spark10_10M["result_time"].mean(),
                         spark10_10M["output_time"].mean()]

index_aqt = ['RDBMS', 'Spark 10 Nodes']

stacked_df = pd.DataFrame({'Query Time': stacked_query_time,
                                     'Result Time': stacked_result_time,
                            'Output Time': stacked_output_time}, index=index_aqt)

ax = stacked_df.plot.bar(rot=0, figsize=(25,20), fontsize=30,
                                    title="Stacked total time comparing RDBMS vs Spark 10 Nodes\n",
                                    width=0.15,
                                    color=['cornflowerblue', 'darkorange', 'mediumseagreen'],
                                    stacked=True)

ax.legend(fontsize=30, facecolor='white')
ax.set_xlabel("\nLines of data", fontsize=30)
ax.set_ylabel("Time in ms\n", fontsize=30)
ax.title.set_fontsize(50)
# for p in ax.patches:
#     str(ax.text(p.get_x() + p.get_width(), p.get_height(), np.round(p.get_height(),decimals=2), fontsize=35))

for p in ax.patches:
    width, height = p.get_width(), p.get_height()
    x, y = p.get_xy() 
    ax.text(x+width*1.4, 
            y+height/2, 
            '{:.0f}'.format(height), 
            horizontalalignment='center', 
            verticalalignment='center', fontsize=20)
# print('Difference between times : \n')
# print(min2_query_time_df['RDBMS'] - min2_query_time_df['Spark 10 Nodes'])
print()
# ax.figure.savefig('Stacked total time comparing RDBMS vs Spark 10 Nodes.png', dpi=200)

# %%
import seaborn as sns

sns.set(style="whitegrid")

tips = sns.load_dataset("tips")

ax = sns.barplot(x="day", y="total_bill", data=tips)
